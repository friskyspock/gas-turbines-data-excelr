# %% [markdown]
# # Neural Networks Assignment
# ## Gas Turbines data
# predicting turbine energy yield (TEY) using ambient variables as features.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV, KFold, train_test_split
from sklearn.metrics import mean_squared_error

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from scikeras.wrappers import KerasRegressor
# Out:
# 2023-05-09 15:08:43.671384: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
data = pd.read_csv('gas_turbines.csv')

# %% [markdown]
# ### Attribute Information:
#
# The explanations of sensor measurements and their brief statistics are given below.
#
# | Variable (Abbr.)                    | Unit | Min    | Max    | Mean   |
# |-------------------------------------|------|--------|--------|--------|
# | Ambient temperature (AT)            | C    | 6.23   | 37.10  | 17.71  |
# |Ambient pressure (AP)                | mbar | 985.85 | 1036.56| 1013.07|
# |Ambient humidity (AH)                | (%)  | 24.08  | 100.20 | 77.87  |
# |Air filter difference pressure (AFDP)| mbar | 2.09   | 7.61   | 3.93   |
# |Gas turbine exhaust pressure (GTEP)  | mbar | 17.70  | 40.72  | 25.56  |
# |Turbine inlet temperature (TIT)      | C    | 1000.85| 1100.89| 1081.43|
# |Turbine after temperature (TAT)      | C    | 511.04 | 550.61 | 546.16 |
# |Compressor discharge pressure (CDP)  | mbar | 9.85   | 15.16  | 12.06  |
# |Turbine energy yield (TEY)           | MWH  | 100.02 | 179.50 | 133.51 |
# |Carbon monoxide (CO)                 | mg/m3| 0.00   | 44.10  | 2.37   |
# |Nitrogen oxides (NOx)                | mg/m3| 25.90  | 119.91 | 65.29  |

# %%
data.head()
# Out:
#        AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0  6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605
# 1  6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598
# 2  6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601
# 3  7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606
# 4  7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612
#
#        CO     NOX
# 0  3.1547  82.722
# 1  3.2363  82.776
# 2  3.2012  82.468
# 3  3.1923  82.670
# 4  3.2484  82.311

# %%
data.isna().sum()
# Out:
# AT      0
# AP      0
# AH      0
# AFDP    0
# GTEP    0
# TIT     0
# TAT     0
# TEY     0
# CDP     0
# CO      0
# NOX     0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Data Visualization

# %%
plt.figure(figsize=(20,15))
for i in range(len(data.columns)):
    plt.subplot(3,4,i+1)
    sns.histplot(data=data, x=data.columns[i], kde=True)

# %% [markdown]
# ### Preparing data for model

# %%
x = data.drop('TEY', axis=1)
y = data['TEY']

# %%
scaler = StandardScaler()
x = pd.DataFrame(scaler.fit_transform(x), columns=x.columns)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x.shape
# Out:
# (15039, 10)

# %% [markdown]
# ### Model Building

# %%
def create_model(units=20, optimizer='adam', activation='relu', dropout_rate=0.0, num_layers=1):
    model = Sequential()
    model.add(Dense(units, input_dim=10, activation=activation))
    model.add(Dropout(dropout_rate))
    
    for i in range(num_layers):
        model.add(Dense(units, activation=activation))
        model.add(Dropout(dropout_rate))

    model.add(Dense(1))
    
    model.compile(loss='mean_squared_error', optimizer=optimizer)
    return model

# %% [markdown]
# ### GridSearchCV
#
# parameters
# - units for hidden layers
# - optimizers
# - activation function
# - dropout rate
# - number of hidden layers

# %%
param_grid = {
    'units': [8, 16, 32],
    'optimizer': ['adam', 'sgd'],
    'activation': ['relu', 'sigmoid'],
    'dropout_rate': [0.0, 0.1, 0.2],
    'num_layers': [1, 2, 3]
}

# %%
model = KerasRegressor(model=create_model, verbose=0, activation='relu', dropout_rate=0.0, num_layers=1, units=8)

# %%
grid = GridSearchCV(estimator=model, param_grid=param_grid, cv=KFold(), verbose=10)
grid_result = grid.fit(x,y)
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# [CV 1/5; 1/108] START activation=relu, dropout_rate=0.0, num_layers=1, optimizer=adam, units=8
# [CV 1/5; 1/108] END activation=relu, dropout_rate=0.0, num_layers=1, optimizer=adam, units=8;, score=-31.489 total time=   2.9s
# [CV 2/5; 1/108] START activation=relu, dropout_rate=0.0, num_layers=1, optimizer=adam, units=8
# [CV 2/5; 1/108] END activation=relu, dropout_rate=0.0, num_layers=1, optimizer=adam, units=8;, score=-115.122 total time=   1.3s
# [CV 3/5; 1/108] START activation=relu, dropout_rate=0.0, num_layers=1, optimizer=adam, units=8
# [CV 3/5; 1/108] END activation=relu, dropout_rate=0.0, num_layers=1, optimizer=adam, units=8;, score=-36.823 total time=   1.3s
# [CV 4/5; 1/108] START activation=relu, dropout_rate=0.0, num_layers=1, optimizer=adam, units=8
# [CV 4/5; 1/108] END activation=relu, dropout_rate=0.0, num_layers=1, optimizer=adam, units=8;, score=-61.741 total time=   1.3s
# [CV 5/5; 1/108] START activation=relu, dropout_rate=0.0, num_layers=1, optimizer=adam, units=8
# [CV 5/5; 1/108] END activation=relu, dropout_rate=0.0, num_layers=1, optimizer=adam, units=8;, score=-54.209 total time=   1.3s
# [CV 1/5; 2/108] START activation=relu, dropout_rate=0.0, num_layers=1, optimizer=adam, units=16
# [CV 1/5; 2/108] END activation=relu, dropout_rate=0.0, num_layers=1, optimizer=adam, units=16;, score=-10.850 total time=   1.4s
# [CV 2/5; 2/108] START activation=relu, dropout_rate=0.0, num_layers=1, optimizer=adam, units=16
# [CV 2/5; 2/108] END activation=relu, dropout_rate=0.0, num_layers=1, optimizer=adam, units=16;, score=-69.790 total time=   1.3s
# [CV 3/5; 2/108] START activation=relu, dropout_rate=0.0, num_layers=1, optimizer=adam, units=16
# [CV 3/5; 2/108] END activation=relu, dropout_rate=0.0, num_layers=1, optimizer=adam, units=16;, score=-14.828 total time=   1.3s
# [CV 4/5; 2/108] START activation=relu, dropout_rate=0.0, num_layers=1, optimizer=adam, units=16
# [CV 4/5; 2/108] END activation=relu, dropout_rate=0.0, num_layers=1, optimizer=adam, units=16;, score=-10.577 total time=   1.3s
# [CV 5/5; 2/108] START activation=relu, dropout_rate=0.0, num_layers=1, optimizer=adam, units=16
# [CV 5/5; 2/108] END activation=relu, dropout_rate=0.0, num_layers=1, optimizer=adam, units=16;, score=-6.679 total time=   1.2s
# [CV 1/5; 3/108] START activation=relu, dropout_rate=0.0, num_layers=1, optimizer=adam, units=32
# [CV 1/5; 3/108] END activation=relu, dropout_rate=0.0, num_layers=1, optimizer=adam, units=32;, score=-2.465 total time=   1.6s
# [CV 2/5; 3/108] START activation=relu, dropout_rate=0.0, num_layers=1, optimizer=adam, units=32
# [CV 2/5; 3/108] END activation=relu, dropout_rate=0.0, num_layers=1, optimizer=adam, units=32;, score=-16.657 total time=   1.4s
# [CV 3/5; 3/108] START activation=relu, dropout_rate=0.0, num_layers=1, optimizer=adam, units=32
# [CV 3/5; 3/108] END activation=relu, dropout_rate=0.0, num_layers=1, optimizer=adam, units=32;, score=-3.015 total time=   1.3s
# [CV 4/5; 3/108] START activation=relu, dropout_rate=0.0, num_layers=1, optimizer=adam, units=32
# [CV 4/5; 3/108] END activation=relu, dropout_rate=0.0, num_layers=1, optimizer=adam, units=32;, score=-1.653 total time=   1.3s
# [CV 5/5; 3/108] START activation=relu, dropout_rate=0.0, num_layers=1, optimizer=adam, units=32
# [CV 5/5; 3/108] END activation=relu, dropout_rate=0.0, num_layers=1, optimizer=adam, units=32;, score=-1.210 total time=   1.3s
# [CV 1/5; 4/108] START activation=relu, dropout_rate=0.0, num_layers=1, optimizer=sgd, units=8
# [CV 1/5; 4/108] END activation=relu, dropout_rate=0.0, num_layers=1, optimizer=sgd, units=8;, score=-25.874 total time=   1.2s
# [CV 2/5; 4/108] START activation=relu, dropout_rate=0.0, num_layers=1, optimizer=sgd, units=8
# [CV 2/5; 4/108] END activation=relu, dropout_rate=0.0, num_layers=1, optimizer=sgd, units=8;, score=-107.084 total time=   1.2s
# [CV 3/5; 4/108] START activation=relu, dropout_rate=0.0, num_layers=1, optimizer=sgd, units=8
# [CV 3/5; 4/108] END activation=relu, dropout_rate=0.0, num_layers=1, optimizer=sgd, units=8;, score=-39.801 total time=   1.2s
# [CV 4/5; 4/108] START activation=relu, dropout_rate=0.0, num_layers=1, optimizer=sgd, units=8
# [CV 4/5; 4/108] END activation=relu, dropout_rate=0.0, num_layers=1, optimizer=sgd, units=8;, score=-61.101 total time=   1.2s
# [CV 5/5; 4/108] START activation=relu, dropout_rate=0.0, num_layers=1, optimizer=sgd, units=8
# [CV 5/5; 4/108] END activation=relu, dropout_rate=0.0, num_layers=1, optimizer=sgd, units=8;, score=-32.328 total time=   1.1s
# [CV 1/5; 5/108] START activation=relu, dropout_rate=0.0, num_layers=1, optimizer=sgd, units=16
# [CV 1/5; 5/108] END activation=relu, dropout_rate=0.0, num_layers=1, optimizer=sgd, units=16;, score=-11.808 total time=   1.2s
# [CV 2/5; 5/108] START activation=relu, dropout_rate=0.0, num_layers=1, optimizer=sgd, units=16
# [CV 2/5; 5/108] END activation=relu, dropout_rate=0.0, num_layers=1, optimizer=sgd, units=16;, score=-37.797 total time=   1.2s
# [CV 3/5; 5/108] START activation=relu, dropout_rate=0.0, num_layers=1, optimizer=sgd, units=16
# [CV 3/5; 5/108] END activation=relu, dropout_rate=0.0, num_layers=1, optimizer=sgd, units=16;, score=-12.366 total time=   1.5s
# [CV 4/5; 5/108] START activation=relu, dropout_rate=0.0, num_layers=1, optimizer=sgd, units=16
# [CV 4/5; 5/108] END activation=relu, dropout_rate=0.0, num_layers=1, optimizer=sgd, units=16;, score=-7.824 total time=   1.3s
# [CV 5/5; 5/108] START activation=relu, dropout_rate=0.0, num_layers=1, optimizer=sgd, units=16
# [CV 5/5; 5/108] END activation=relu, dropout_rate=0.0, num_layers=1, optimizer=sgd, units=16;, score=-10.349 total time=   1.2s
# [CV 1/5; 6/108] START activation=relu, dropout_rate=0.0, num_layers=1, optimizer=sgd, units=32
# [CV 1/5; 6/108] END activation=relu, dropout_rate=0.0, num_layers=1, optimizer=sgd, units=32;, score=-2.006 total time=   1.3s
# [CV 2/5; 6/108] START activation=relu, dropout_rate=0.0, num_layers=1, optimizer=sgd, units=32
# [CV 2/5; 6/108] END activation=relu, dropout_rate=0.0, num_layers=1, optimizer=sgd, units=32;, score=-19.923 total time=   1.2s
# [CV 3/5; 6/108] START activation=relu, dropout_rate=0.0, num_layers=1, optimizer=sgd, units=32
# [CV 3/5; 6/108] END activation=relu, dropout_rate=0.0, num_layers=1, optimizer=sgd, units=32;, score=-2.145 total time=   1.6s
# [CV 4/5; 6/108] START activation=relu, dropout_rate=0.0, num_layers=1, optimizer=sgd, units=32
# [CV 4/5; 6/108] END activation=relu, dropout_rate=0.0, num_layers=1, optimizer=sgd, units=32;, score=-0.996 total time=   1.3s
# [CV 5/5; 6/108] START activation=relu, dropout_rate=0.0, num_layers=1, optimizer=sgd, units=32
# [CV 5/5; 6/108] END activation=relu, dropout_rate=0.0, num_layers=1, optimizer=sgd, units=32;, score=-0.644 total time=   1.3s
# [CV 1/5; 7/108] START activation=relu, dropout_rate=0.0, num_layers=2, optimizer=adam, units=8
# [CV 1/5; 7/108] END activation=relu, dropout_rate=0.0, num_layers=2, optimizer=adam, units=8;, score=-11.398 total time=   1.5s
# [CV 2/5; 7/108] START activation=relu, dropout_rate=0.0, num_layers=2, optimizer=adam, units=8
# [CV 2/5; 7/108] END activation=relu, dropout_rate=0.0, num_layers=2, optimizer=adam, units=8;, score=-25.636 total time=   1.7s
# [CV 3/5; 7/108] START activation=relu, dropout_rate=0.0, num_layers=2, optimizer=adam, units=8
# [CV 3/5; 7/108] END activation=relu, dropout_rate=0.0, num_layers=2, optimizer=adam, units=8;, score=-4.756 total time=   1.5s
# [CV 4/5; 7/108] START activation=relu, dropout_rate=0.0, num_layers=2, optimizer=adam, units=8
# [CV 4/5; 7/108] END activation=relu, dropout_rate=0.0, num_layers=2, optimizer=adam, units=8;, score=-8.454 total time=   1.4s
# [CV 5/5; 7/108] START activation=relu, dropout_rate=0.0, num_layers=2, optimizer=adam, units=8
# [CV 5/5; 7/108] END activation=relu, dropout_rate=0.0, num_layers=2, optimizer=adam, units=8;, score=-13.086 total time=   1.7s
# [CV 1/5; 8/108] START activation=relu, dropout_rate=0.0, num_layers=2, optimizer=adam, units=16
# [CV 1/5; 8/108] END activation=relu, dropout_rate=0.0, num_layers=2, optimizer=adam, units=16;, score=-3.166 total time=   1.4s
# [CV 2/5; 8/108] START activation=relu, dropout_rate=0.0, num_layers=2, optimizer=adam, units=16
# [CV 2/5; 8/108] END activation=relu, dropout_rate=0.0, num_layers=2, optimizer=adam, units=16;, score=-10.368 total time=   1.4s
# [CV 3/5; 8/108] START activation=relu, dropout_rate=0.0, num_layers=2, optimizer=adam, units=16
# [CV 3/5; 8/108] END activation=relu, dropout_rate=0.0, num_layers=2, optimizer=adam, units=16;, score=-0.773 total time=   1.5s
# [CV 4/5; 8/108] START activation=relu, dropout_rate=0.0, num_layers=2, optimizer=adam, units=16
# [CV 4/5; 8/108] END activation=relu, dropout_rate=0.0, num_layers=2, optimizer=adam, units=16;, score=-1.089 total time=   1.4s
# [CV 5/5; 8/108] START activation=relu, dropout_rate=0.0, num_layers=2, optimizer=adam, units=16
# [CV 5/5; 8/108] END activation=relu, dropout_rate=0.0, num_layers=2, optimizer=adam, units=16;, score=-0.342 total time=   1.3s
# [CV 1/5; 9/108] START activation=relu, dropout_rate=0.0, num_layers=2, optimizer=adam, units=32
# [CV 1/5; 9/108] END activation=relu, dropout_rate=0.0, num_layers=2, optimizer=adam, units=32;, score=-0.477 total time=   1.4s
# [CV 2/5; 9/108] START activation=relu, dropout_rate=0.0, num_layers=2, optimizer=adam, units=32
# [CV 2/5; 9/108] END activation=relu, dropout_rate=0.0, num_layers=2, optimizer=adam, units=32;, score=-3.049 total time=   1.4s
# [CV 3/5; 9/108] START activation=relu, dropout_rate=0.0, num_layers=2, optimizer=adam, units=32
# [CV 3/5; 9/108] END activation=relu, dropout_rate=0.0, num_layers=2, optimizer=adam, units=32;, score=-0.017 total time=   1.4s
# [CV 4/5; 9/108] START activation=relu, dropout_rate=0.0, num_layers=2, optimizer=adam, units=32
# [CV 4/5; 9/108] END activation=relu, dropout_rate=0.0, num_layers=2, optimizer=adam, units=32;, score=-0.128 total time=   1.3s
# [CV 5/5; 9/108] START activation=relu, dropout_rate=0.0, num_layers=2, optimizer=adam, units=32
# [CV 5/5; 9/108] END activation=relu, dropout_rate=0.0, num_layers=2, optimizer=adam, units=32;, score=0.066 total time=   1.3s
# [CV 1/5; 10/108] START activation=relu, dropout_rate=0.0, num_layers=2, optimizer=sgd, units=8
# [CV 1/5; 10/108] END activation=relu, dropout_rate=0.0, num_layers=2, optimizer=sgd, units=8;, score=-5.972 total time=   1.7s
# [CV 2/5; 10/108] START activation=relu, dropout_rate=0.0, num_layers=2, optimizer=sgd, units=8
# [CV 2/5; 10/108] END activation=relu, dropout_rate=0.0, num_layers=2, optimizer=sgd, units=8;, score=-79.515 total time=   1.5s
# [CV 3/5; 10/108] START activation=relu, dropout_rate=0.0, num_layers=2, optimizer=sgd, units=8
# [CV 3/5; 10/108] END activation=relu, dropout_rate=0.0, num_layers=2, optimizer=sgd, units=8;, score=-9.379 total time=   1.5s
# [CV 4/5; 10/108] START activation=relu, dropout_rate=0.0, num_layers=2, optimizer=sgd, units=8
# [CV 4/5; 10/108] END activation=relu, dropout_rate=0.0, num_layers=2, optimizer=sgd, units=8;, score=-16.811 total time=   1.5s
# [CV 5/5; 10/108] START activation=relu, dropout_rate=0.0, num_layers=2, optimizer=sgd, units=8
# [CV 5/5; 10/108] END activation=relu, dropout_rate=0.0, num_layers=2, optimizer=sgd, units=8;, score=-5.340 total time=   1.4s
# [CV 1/5; 11/108] START activation=relu, dropout_rate=0.0, num_layers=2, optimizer=sgd, units=16
# [CV 1/5; 11/108] END activation=relu, dropout_rate=0.0, num_layers=2, optimizer=sgd, units=16;, score=-1.066 total time=   1.5s
# [CV 2/5; 11/108] START activation=relu, dropout_rate=0.0, num_layers=2, optimizer=sgd, units=16
# [CV 2/5; 11/108] END activation=relu, dropout_rate=0.0, num_layers=2, optimizer=sgd, units=16;, score=-9.070 total time=   1.5s
# [CV 3/5; 11/108] START activation=relu, dropout_rate=0.0, num_layers=2, optimizer=sgd, units=16
# [CV 3/5; 11/108] END activation=relu, dropout_rate=0.0, num_layers=2, optimizer=sgd, units=16;, score=-0.998 total time=   1.5s
# [CV 4/5; 11/108] START activation=relu, dropout_rate=0.0, num_layers=2, optimizer=sgd, units=16
# [CV 4/5; 11/108] END activation=relu, dropout_rate=0.0, num_layers=2, optimizer=sgd, units=16;, score=-0.624 total time=   1.5s
# [CV 5/5; 11/108] START activation=relu, dropout_rate=0.0, num_layers=2, optimizer=sgd, units=16
# [CV 5/5; 11/108] END activation=relu, dropout_rate=0.0, num_layers=2, optimizer=sgd, units=16;, score=-0.543 total time=   1.4s
# [CV 1/5; 12/108] START activation=relu, dropout_rate=0.0, num_layers=2, optimizer=sgd, units=32
# [CV 1/5; 12/108] END activation=relu, dropout_rate=0.0, num_layers=2, optimizer=sgd, units=32;, score=-0.231 total time=   1.4s
# [CV 2/5; 12/108] START activation=relu, dropout_rate=0.0, num_layers=2, optimizer=sgd, units=32
# [CV 2/5; 12/108] END activation=relu, dropout_rate=0.0, num_layers=2, optimizer=sgd, units=32;, score=-4.377 total time=   1.9s
# [CV 3/5; 12/108] START activation=relu, dropout_rate=0.0, num_layers=2, optimizer=sgd, units=32
# [CV 3/5; 12/108] END activation=relu, dropout_rate=0.0, num_layers=2, optimizer=sgd, units=32;, score=-0.136 total time=   1.5s
# [CV 4/5; 12/108] START activation=relu, dropout_rate=0.0, num_layers=2, optimizer=sgd, units=32
# [CV 4/5; 12/108] END activation=relu, dropout_rate=0.0, num_layers=2, optimizer=sgd, units=32;, score=-0.159 total time=   1.5s
# [CV 5/5; 12/108] START activation=relu, dropout_rate=0.0, num_layers=2, optimizer=sgd, units=32
# [CV 5/5; 12/108] END activation=relu, dropout_rate=0.0, num_layers=2, optimizer=sgd, units=32;, score=0.193 total time=   1.4s
# [CV 1/5; 13/108] START activation=relu, dropout_rate=0.0, num_layers=3, optimizer=adam, units=8
# [CV 1/5; 13/108] END activation=relu, dropout_rate=0.0, num_layers=3, optimizer=adam, units=8;, score=-4.752 total time=   1.6s
# [CV 2/5; 13/108] START activation=relu, dropout_rate=0.0, num_layers=3, optimizer=adam, units=8
# [CV 2/5; 13/108] END activation=relu, dropout_rate=0.0, num_layers=3, optimizer=adam, units=8;, score=-22.734 total time=   1.6s
# [CV 3/5; 13/108] START activation=relu, dropout_rate=0.0, num_layers=3, optimizer=adam, units=8
# [CV 3/5; 13/108] END activation=relu, dropout_rate=0.0, num_layers=3, optimizer=adam, units=8;, score=-6.206 total time=   1.6s
# [CV 4/5; 13/108] START activation=relu, dropout_rate=0.0, num_layers=3, optimizer=adam, units=8
# [CV 4/5; 13/108] END activation=relu, dropout_rate=0.0, num_layers=3, optimizer=adam, units=8;, score=-3.219 total time=   1.6s
# [CV 5/5; 13/108] START activation=relu, dropout_rate=0.0, num_layers=3, optimizer=adam, units=8
# [CV 5/5; 13/108] END activation=relu, dropout_rate=0.0, num_layers=3, optimizer=adam, units=8;, score=-4.012 total time=   1.4s
# [CV 1/5; 14/108] START activation=relu, dropout_rate=0.0, num_layers=3, optimizer=adam, units=16
# [CV 1/5; 14/108] END activation=relu, dropout_rate=0.0, num_layers=3, optimizer=adam, units=16;, score=-0.557 total time=   1.5s
# [CV 2/5; 14/108] START activation=relu, dropout_rate=0.0, num_layers=3, optimizer=adam, units=16
# [CV 2/5; 14/108] END activation=relu, dropout_rate=0.0, num_layers=3, optimizer=adam, units=16;, score=-3.885 total time=   2.0s
# [CV 3/5; 14/108] START activation=relu, dropout_rate=0.0, num_layers=3, optimizer=adam, units=16
# [CV 3/5; 14/108] END activation=relu, dropout_rate=0.0, num_layers=3, optimizer=adam, units=16;, score=0.011 total time=   1.7s
# [CV 4/5; 14/108] START activation=relu, dropout_rate=0.0, num_layers=3, optimizer=adam, units=16
# [CV 4/5; 14/108] END activation=relu, dropout_rate=0.0, num_layers=3, optimizer=adam, units=16;, score=-2.001 total time=   1.6s
# [CV 5/5; 14/108] START activation=relu, dropout_rate=0.0, num_layers=3, optimizer=adam, units=16
# [CV 5/5; 14/108] END activation=relu, dropout_rate=0.0, num_layers=3, optimizer=adam, units=16;, score=-0.311 total time=   1.6s
# [CV 1/5; 15/108] START activation=relu, dropout_rate=0.0, num_layers=3, optimizer=adam, units=32
# [CV 1/5; 15/108] END activation=relu, dropout_rate=0.0, num_layers=3, optimizer=adam, units=32;, score=0.026 total time=   1.7s
# [CV 2/5; 15/108] START activation=relu, dropout_rate=0.0, num_layers=3, optimizer=adam, units=32
# [CV 2/5; 15/108] END activation=relu, dropout_rate=0.0, num_layers=3, optimizer=adam, units=32;, score=-2.027 total time=   1.7s
# [CV 3/5; 15/108] START activation=relu, dropout_rate=0.0, num_layers=3, optimizer=adam, units=32
# [CV 3/5; 15/108] END activation=relu, dropout_rate=0.0, num_layers=3, optimizer=adam, units=32;, score=0.033 total time=   1.7s
# [CV 4/5; 15/108] START activation=relu, dropout_rate=0.0, num_layers=3, optimizer=adam, units=32
# [CV 4/5; 15/108] END activation=relu, dropout_rate=0.0, num_layers=3, optimizer=adam, units=32;, score=0.216 total time=   1.7s
# [CV 5/5; 15/108] START activation=relu, dropout_rate=0.0, num_layers=3, optimizer=adam, units=32
# [CV 5/5; 15/108] END activation=relu, dropout_rate=0.0, num_layers=3, optimizer=adam, units=32;, score=0.073 total time=   1.6s
# [CV 1/5; 16/108] START activation=relu, dropout_rate=0.0, num_layers=3, optimizer=sgd, units=8
# [CV 1/5; 16/108] END activation=relu, dropout_rate=0.0, num_layers=3, optimizer=sgd, units=8;, score=-3.059 total time=   1.6s
# [CV 2/5; 16/108] START activation=relu, dropout_rate=0.0, num_layers=3, optimizer=sgd, units=8
# [CV 2/5; 16/108] END activation=relu, dropout_rate=0.0, num_layers=3, optimizer=sgd, units=8;, score=-28.374 total time=   2.2s
# [CV 3/5; 16/108] START activation=relu, dropout_rate=0.0, num_layers=3, optimizer=sgd, units=8
# [CV 3/5; 16/108] END activation=relu, dropout_rate=0.0, num_layers=3, optimizer=sgd, units=8;, score=-2.533 total time=   1.7s
# [CV 4/5; 16/108] START activation=relu, dropout_rate=0.0, num_layers=3, optimizer=sgd, units=8
# [CV 4/5; 16/108] END activation=relu, dropout_rate=0.0, num_layers=3, optimizer=sgd, units=8;, score=-1.698 total time=   1.6s
# [CV 5/5; 16/108] START activation=relu, dropout_rate=0.0, num_layers=3, optimizer=sgd, units=8
# [CV 5/5; 16/108] END activation=relu, dropout_rate=0.0, num_layers=3, optimizer=sgd, units=8;, score=-2.247 total time=   1.6s
# [CV 1/5; 17/108] START activation=relu, dropout_rate=0.0, num_layers=3, optimizer=sgd, units=16
# [CV 1/5; 17/108] END activation=relu, dropout_rate=0.0, num_layers=3, optimizer=sgd, units=16;, score=0.135 total time=   1.6s
# [CV 2/5; 17/108] START activation=relu, dropout_rate=0.0, num_layers=3, optimizer=sgd, units=16
# [CV 2/5; 17/108] END activation=relu, dropout_rate=0.0, num_layers=3, optimizer=sgd, units=16;, score=-5.119 total time=   1.5s
# [CV 3/5; 17/108] START activation=relu, dropout_rate=0.0, num_layers=3, optimizer=sgd, units=16
# [CV 3/5; 17/108] END activation=relu, dropout_rate=0.0, num_layers=3, optimizer=sgd, units=16;, score=-0.228 total time=   1.5s
# [CV 4/5; 17/108] START activation=relu, dropout_rate=0.0, num_layers=3, optimizer=sgd, units=16
# [CV 4/5; 17/108] END activation=relu, dropout_rate=0.0, num_layers=3, optimizer=sgd, units=16;, score=-0.510 total time=   1.5s
# [CV 5/5; 17/108] START activation=relu, dropout_rate=0.0, num_layers=3, optimizer=sgd, units=16
# [CV 5/5; 17/108] END activation=relu, dropout_rate=0.0, num_layers=3, optimizer=sgd, units=16;, score=-0.260 total time=   1.4s
# [CV 1/5; 18/108] START activation=relu, dropout_rate=0.0, num_layers=3, optimizer=sgd, units=32
# [CV 1/5; 18/108] END activation=relu, dropout_rate=0.0, num_layers=3, optimizer=sgd, units=32;, score=-0.064 total time=   1.5s
# [CV 2/5; 18/108] START activation=relu, dropout_rate=0.0, num_layers=3, optimizer=sgd, units=32
# [CV 2/5; 18/108] END activation=relu, dropout_rate=0.0, num_layers=3, optimizer=sgd, units=32;, score=-3.280 total time=   2.1s
# [CV 3/5; 18/108] START activation=relu, dropout_rate=0.0, num_layers=3, optimizer=sgd, units=32
# [CV 3/5; 18/108] END activation=relu, dropout_rate=0.0, num_layers=3, optimizer=sgd, units=32;, score=0.097 total time=   1.7s
# [CV 4/5; 18/108] START activation=relu, dropout_rate=0.0, num_layers=3, optimizer=sgd, units=32
# [CV 4/5; 18/108] END activation=relu, dropout_rate=0.0, num_layers=3, optimizer=sgd, units=32;, score=0.042 total time=   1.7s
# [CV 5/5; 18/108] START activation=relu, dropout_rate=0.0, num_layers=3, optimizer=sgd, units=32
# [CV 5/5; 18/108] END activation=relu, dropout_rate=0.0, num_layers=3, optimizer=sgd, units=32;, score=0.273 total time=   1.7s
# [CV 1/5; 19/108] START activation=relu, dropout_rate=0.1, num_layers=1, optimizer=adam, units=8
# [CV 1/5; 19/108] END activation=relu, dropout_rate=0.1, num_layers=1, optimizer=adam, units=8;, score=-46.068 total time=   1.5s
# [CV 2/5; 19/108] START activation=relu, dropout_rate=0.1, num_layers=1, optimizer=adam, units=8
# [CV 2/5; 19/108] END activation=relu, dropout_rate=0.1, num_layers=1, optimizer=adam, units=8;, score=-121.242 total time=   1.5s
# [CV 3/5; 19/108] START activation=relu, dropout_rate=0.1, num_layers=1, optimizer=adam, units=8
# [CV 3/5; 19/108] END activation=relu, dropout_rate=0.1, num_layers=1, optimizer=adam, units=8;, score=-48.209 total time=   1.4s
# [CV 4/5; 19/108] START activation=relu, dropout_rate=0.1, num_layers=1, optimizer=adam, units=8
# [CV 4/5; 19/108] END activation=relu, dropout_rate=0.1, num_layers=1, optimizer=adam, units=8;, score=-53.806 total time=   1.4s
# [CV 5/5; 19/108] START activation=relu, dropout_rate=0.1, num_layers=1, optimizer=adam, units=8
# [CV 5/5; 19/108] END activation=relu, dropout_rate=0.1, num_layers=1, optimizer=adam, units=8;, score=-45.253 total time=   1.3s
# [CV 1/5; 20/108] START activation=relu, dropout_rate=0.1, num_layers=1, optimizer=adam, units=16
# [CV 1/5; 20/108] END activation=relu, dropout_rate=0.1, num_layers=1, optimizer=adam, units=16;, score=-12.914 total time=   1.3s
# [CV 2/5; 20/108] START activation=relu, dropout_rate=0.1, num_layers=1, optimizer=adam, units=16
# [CV 2/5; 20/108] END activation=relu, dropout_rate=0.1, num_layers=1, optimizer=adam, units=16;, score=-39.627 total time=   1.3s
# [CV 3/5; 20/108] START activation=relu, dropout_rate=0.1, num_layers=1, optimizer=adam, units=16
# [CV 3/5; 20/108] END activation=relu, dropout_rate=0.1, num_layers=1, optimizer=adam, units=16;, score=-15.739 total time=   1.4s
# [CV 4/5; 20/108] START activation=relu, dropout_rate=0.1, num_layers=1, optimizer=adam, units=16
# [CV 4/5; 20/108] END activation=relu, dropout_rate=0.1, num_layers=1, optimizer=adam, units=16;, score=-11.810 total time=   1.8s
# [CV 5/5; 20/108] START activation=relu, dropout_rate=0.1, num_layers=1, optimizer=adam, units=16
# [CV 5/5; 20/108] END activation=relu, dropout_rate=0.1, num_layers=1, optimizer=adam, units=16;, score=-13.371 total time=   1.4s
# [CV 1/5; 21/108] START activation=relu, dropout_rate=0.1, num_layers=1, optimizer=adam, units=32
# [CV 1/5; 21/108] END activation=relu, dropout_rate=0.1, num_layers=1, optimizer=adam, units=32;, score=-2.053 total time=   1.5s
# [CV 2/5; 21/108] START activation=relu, dropout_rate=0.1, num_layers=1, optimizer=adam, units=32
# [CV 2/5; 21/108] END activation=relu, dropout_rate=0.1, num_layers=1, optimizer=adam, units=32;, score=-15.189 total time=   1.4s
# [CV 3/5; 21/108] START activation=relu, dropout_rate=0.1, num_layers=1, optimizer=adam, units=32
# [CV 3/5; 21/108] END activation=relu, dropout_rate=0.1, num_layers=1, optimizer=adam, units=32;, score=-2.771 total time=   1.4s
# [CV 4/5; 21/108] START activation=relu, dropout_rate=0.1, num_layers=1, optimizer=adam, units=32
# [CV 4/5; 21/108] END activation=relu, dropout_rate=0.1, num_layers=1, optimizer=adam, units=32;, score=-1.939 total time=   1.4s
# [CV 5/5; 21/108] START activation=relu, dropout_rate=0.1, num_layers=1, optimizer=adam, units=32
# [CV 5/5; 21/108] END activation=relu, dropout_rate=0.1, num_layers=1, optimizer=adam, units=32;, score=-1.360 total time=   1.2s
# [CV 1/5; 22/108] START activation=relu, dropout_rate=0.1, num_layers=1, optimizer=sgd, units=8
# [CV 1/5; 22/108] END activation=relu, dropout_rate=0.1, num_layers=1, optimizer=sgd, units=8;, score=-27.958 total time=   1.3s
# [CV 2/5; 22/108] START activation=relu, dropout_rate=0.1, num_layers=1, optimizer=sgd, units=8
# [CV 2/5; 22/108] END activation=relu, dropout_rate=0.1, num_layers=1, optimizer=sgd, units=8;, score=-134.789 total time=   1.4s
# [CV 3/5; 22/108] START activation=relu, dropout_rate=0.1, num_layers=1, optimizer=sgd, units=8
# [CV 3/5; 22/108] END activation=relu, dropout_rate=0.1, num_layers=1, optimizer=sgd, units=8;, score=-39.794 total time=   1.3s
# [CV 4/5; 22/108] START activation=relu, dropout_rate=0.1, num_layers=1, optimizer=sgd, units=8
# [CV 4/5; 22/108] END activation=relu, dropout_rate=0.1, num_layers=1, optimizer=sgd, units=8;, score=-63.070 total time=   1.4s
# [CV 5/5; 22/108] START activation=relu, dropout_rate=0.1, num_layers=1, optimizer=sgd, units=8
# [CV 5/5; 22/108] END activation=relu, dropout_rate=0.1, num_layers=1, optimizer=sgd, units=8;, score=-34.316 total time=   1.3s
# [CV 1/5; 23/108] START activation=relu, dropout_rate=0.1, num_layers=1, optimizer=sgd, units=16
# [CV 1/5; 23/108] END activation=relu, dropout_rate=0.1, num_layers=1, optimizer=sgd, units=16;, score=-9.241 total time=   1.8s
# [CV 2/5; 23/108] START activation=relu, dropout_rate=0.1, num_layers=1, optimizer=sgd, units=16
# [CV 2/5; 23/108] END activation=relu, dropout_rate=0.1, num_layers=1, optimizer=sgd, units=16;, score=-37.207 total time=   1.5s
# [CV 3/5; 23/108] START activation=relu, dropout_rate=0.1, num_layers=1, optimizer=sgd, units=16
# [CV 3/5; 23/108] END activation=relu, dropout_rate=0.1, num_layers=1, optimizer=sgd, units=16;, score=-17.036 total time=   1.4s
# [CV 4/5; 23/108] START activation=relu, dropout_rate=0.1, num_layers=1, optimizer=sgd, units=16
# [CV 4/5; 23/108] END activation=relu, dropout_rate=0.1, num_layers=1, optimizer=sgd, units=16;, score=-12.975 total time=   1.4s
# [CV 5/5; 23/108] START activation=relu, dropout_rate=0.1, num_layers=1, optimizer=sgd, units=16
# [CV 5/5; 23/108] END activation=relu, dropout_rate=0.1, num_layers=1, optimizer=sgd, units=16;, score=-9.359 total time=   1.4s
# [CV 1/5; 24/108] START activation=relu, dropout_rate=0.1, num_layers=1, optimizer=sgd, units=32
# [CV 1/5; 24/108] END activation=relu, dropout_rate=0.1, num_layers=1, optimizer=sgd, units=32;, score=-1.609 total time=   1.4s
# [CV 2/5; 24/108] START activation=relu, dropout_rate=0.1, num_layers=1, optimizer=sgd, units=32
# [CV 2/5; 24/108] END activation=relu, dropout_rate=0.1, num_layers=1, optimizer=sgd, units=32;, score=-10.137 total time=   1.5s
# [CV 3/5; 24/108] START activation=relu, dropout_rate=0.1, num_layers=1, optimizer=sgd, units=32
# [CV 3/5; 24/108] END activation=relu, dropout_rate=0.1, num_layers=1, optimizer=sgd, units=32;, score=-2.387 total time=   1.5s
# [CV 4/5; 24/108] START activation=relu, dropout_rate=0.1, num_layers=1, optimizer=sgd, units=32
# [CV 4/5; 24/108] END activation=relu, dropout_rate=0.1, num_layers=1, optimizer=sgd, units=32;, score=-2.683 total time=   1.4s
# [CV 5/5; 24/108] START activation=relu, dropout_rate=0.1, num_layers=1, optimizer=sgd, units=32
# [CV 5/5; 24/108] END activation=relu, dropout_rate=0.1, num_layers=1, optimizer=sgd, units=32;, score=-1.597 total time=   1.4s
# [CV 1/5; 25/108] START activation=relu, dropout_rate=0.1, num_layers=2, optimizer=adam, units=8
# [CV 1/5; 25/108] END activation=relu, dropout_rate=0.1, num_layers=2, optimizer=adam, units=8;, score=-8.837 total time=   1.6s
# [CV 2/5; 25/108] START activation=relu, dropout_rate=0.1, num_layers=2, optimizer=adam, units=8
# [CV 2/5; 25/108] END activation=relu, dropout_rate=0.1, num_layers=2, optimizer=adam, units=8;, score=-39.860 total time=   1.5s
# [CV 3/5; 25/108] START activation=relu, dropout_rate=0.1, num_layers=2, optimizer=adam, units=8
# [CV 3/5; 25/108] END activation=relu, dropout_rate=0.1, num_layers=2, optimizer=adam, units=8;, score=-15.682 total time=   2.0s
# [CV 4/5; 25/108] START activation=relu, dropout_rate=0.1, num_layers=2, optimizer=adam, units=8
# [CV 4/5; 25/108] END activation=relu, dropout_rate=0.1, num_layers=2, optimizer=adam, units=8;, score=-27.767 total time=   1.6s
# [CV 5/5; 25/108] START activation=relu, dropout_rate=0.1, num_layers=2, optimizer=adam, units=8
# [CV 5/5; 25/108] END activation=relu, dropout_rate=0.1, num_layers=2, optimizer=adam, units=8;, score=-2.632 total time=   1.5s
# [CV 1/5; 26/108] START activation=relu, dropout_rate=0.1, num_layers=2, optimizer=adam, units=16
# [CV 1/5; 26/108] END activation=relu, dropout_rate=0.1, num_layers=2, optimizer=adam, units=16;, score=-1.981 total time=   1.6s
# [CV 2/5; 26/108] START activation=relu, dropout_rate=0.1, num_layers=2, optimizer=adam, units=16
# [CV 2/5; 26/108] END activation=relu, dropout_rate=0.1, num_layers=2, optimizer=adam, units=16;, score=-13.792 total time=   1.6s
# [CV 3/5; 26/108] START activation=relu, dropout_rate=0.1, num_layers=2, optimizer=adam, units=16
# [CV 3/5; 26/108] END activation=relu, dropout_rate=0.1, num_layers=2, optimizer=adam, units=16;, score=-2.702 total time=   1.6s
# [CV 4/5; 26/108] START activation=relu, dropout_rate=0.1, num_layers=2, optimizer=adam, units=16
# [CV 4/5; 26/108] END activation=relu, dropout_rate=0.1, num_layers=2, optimizer=adam, units=16;, score=-0.553 total time=   1.5s
# [CV 5/5; 26/108] START activation=relu, dropout_rate=0.1, num_layers=2, optimizer=adam, units=16
# [CV 5/5; 26/108] END activation=relu, dropout_rate=0.1, num_layers=2, optimizer=adam, units=16;, score=-0.937 total time=   1.5s
# [CV 1/5; 27/108] START activation=relu, dropout_rate=0.1, num_layers=2, optimizer=adam, units=32
# [CV 1/5; 27/108] END activation=relu, dropout_rate=0.1, num_layers=2, optimizer=adam, units=32;, score=-0.212 total time=   1.7s
# [CV 2/5; 27/108] START activation=relu, dropout_rate=0.1, num_layers=2, optimizer=adam, units=32
# [CV 2/5; 27/108] END activation=relu, dropout_rate=0.1, num_layers=2, optimizer=adam, units=32;, score=-3.150 total time=   1.6s
# [CV 3/5; 27/108] START activation=relu, dropout_rate=0.1, num_layers=2, optimizer=adam, units=32
# [CV 3/5; 27/108] END activation=relu, dropout_rate=0.1, num_layers=2, optimizer=adam, units=32;, score=-0.465 total time=   2.2s
# [CV 4/5; 27/108] START activation=relu, dropout_rate=0.1, num_layers=2, optimizer=adam, units=32
# [CV 4/5; 27/108] END activation=relu, dropout_rate=0.1, num_layers=2, optimizer=adam, units=32;, score=-0.382 total time=   1.7s
# [CV 5/5; 27/108] START activation=relu, dropout_rate=0.1, num_layers=2, optimizer=adam, units=32
# [CV 5/5; 27/108] END activation=relu, dropout_rate=0.1, num_layers=2, optimizer=adam, units=32;, score=0.020 total time=   1.7s
# [CV 1/5; 28/108] START activation=relu, dropout_rate=0.1, num_layers=2, optimizer=sgd, units=8
# [CV 1/5; 28/108] END activation=relu, dropout_rate=0.1, num_layers=2, optimizer=sgd, units=8;, score=-8.105 total time=   1.7s
# [CV 2/5; 28/108] START activation=relu, dropout_rate=0.1, num_layers=2, optimizer=sgd, units=8
# [CV 2/5; 28/108] END activation=relu, dropout_rate=0.1, num_layers=2, optimizer=sgd, units=8;, score=-59.496 total time=   1.7s
# [CV 3/5; 28/108] START activation=relu, dropout_rate=0.1, num_layers=2, optimizer=sgd, units=8
# [CV 3/5; 28/108] END activation=relu, dropout_rate=0.1, num_layers=2, optimizer=sgd, units=8;, score=-6.058 total time=   1.7s
# [CV 4/5; 28/108] START activation=relu, dropout_rate=0.1, num_layers=2, optimizer=sgd, units=8
# [CV 4/5; 28/108] END activation=relu, dropout_rate=0.1, num_layers=2, optimizer=sgd, units=8;, score=-6.944 total time=   1.6s
# [CV 5/5; 28/108] START activation=relu, dropout_rate=0.1, num_layers=2, optimizer=sgd, units=8
# [CV 5/5; 28/108] END activation=relu, dropout_rate=0.1, num_layers=2, optimizer=sgd, units=8;, score=-3.766 total time=   1.5s
# [CV 1/5; 29/108] START activation=relu, dropout_rate=0.1, num_layers=2, optimizer=sgd, units=16
# [CV 1/5; 29/108] END activation=relu, dropout_rate=0.1, num_layers=2, optimizer=sgd, units=16;, score=-0.877 total time=   1.6s
# [CV 2/5; 29/108] START activation=relu, dropout_rate=0.1, num_layers=2, optimizer=sgd, units=16
# [CV 2/5; 29/108] END activation=relu, dropout_rate=0.1, num_layers=2, optimizer=sgd, units=16;, score=-10.790 total time=   1.6s
# [CV 3/5; 29/108] START activation=relu, dropout_rate=0.1, num_layers=2, optimizer=sgd, units=16
# [CV 3/5; 29/108] END activation=relu, dropout_rate=0.1, num_layers=2, optimizer=sgd, units=16;, score=-1.656 total time=   2.1s
# [CV 4/5; 29/108] START activation=relu, dropout_rate=0.1, num_layers=2, optimizer=sgd, units=16
# [CV 4/5; 29/108] END activation=relu, dropout_rate=0.1, num_layers=2, optimizer=sgd, units=16;, score=-1.092 total time=   1.6s
# [CV 5/5; 29/108] START activation=relu, dropout_rate=0.1, num_layers=2, optimizer=sgd, units=16
# [CV 5/5; 29/108] END activation=relu, dropout_rate=0.1, num_layers=2, optimizer=sgd, units=16;, score=-0.964 total time=   1.5s
# [CV 1/5; 30/108] START activation=relu, dropout_rate=0.1, num_layers=2, optimizer=sgd, units=32
# [CV 1/5; 30/108] END activation=relu, dropout_rate=0.1, num_layers=2, optimizer=sgd, units=32;, score=-0.046 total time=   1.6s
# [CV 2/5; 30/108] START activation=relu, dropout_rate=0.1, num_layers=2, optimizer=sgd, units=32
# [CV 2/5; 30/108] END activation=relu, dropout_rate=0.1, num_layers=2, optimizer=sgd, units=32;, score=-3.685 total time=   1.6s
# [CV 3/5; 30/108] START activation=relu, dropout_rate=0.1, num_layers=2, optimizer=sgd, units=32
# [CV 3/5; 30/108] END activation=relu, dropout_rate=0.1, num_layers=2, optimizer=sgd, units=32;, score=0.123 total time=   1.6s
# [CV 4/5; 30/108] START activation=relu, dropout_rate=0.1, num_layers=2, optimizer=sgd, units=32
# [CV 4/5; 30/108] END activation=relu, dropout_rate=0.1, num_layers=2, optimizer=sgd, units=32;, score=-0.238 total time=   1.6s
# [CV 5/5; 30/108] START activation=relu, dropout_rate=0.1, num_layers=2, optimizer=sgd, units=32
# [CV 5/5; 30/108] END activation=relu, dropout_rate=0.1, num_layers=2, optimizer=sgd, units=32;, score=0.011 total time=   1.5s
# [CV 1/5; 31/108] START activation=relu, dropout_rate=0.1, num_layers=3, optimizer=adam, units=8
# [CV 1/5; 31/108] END activation=relu, dropout_rate=0.1, num_layers=3, optimizer=adam, units=8;, score=-3.847 total time=   1.7s
# [CV 2/5; 31/108] START activation=relu, dropout_rate=0.1, num_layers=3, optimizer=adam, units=8
# [CV 2/5; 31/108] END activation=relu, dropout_rate=0.1, num_layers=3, optimizer=adam, units=8;, score=-22.217 total time=   2.2s
# [CV 3/5; 31/108] START activation=relu, dropout_rate=0.1, num_layers=3, optimizer=adam, units=8
# [CV 3/5; 31/108] END activation=relu, dropout_rate=0.1, num_layers=3, optimizer=adam, units=8;, score=-3.129 total time=   1.9s
# [CV 4/5; 31/108] START activation=relu, dropout_rate=0.1, num_layers=3, optimizer=adam, units=8
# [CV 4/5; 31/108] END activation=relu, dropout_rate=0.1, num_layers=3, optimizer=adam, units=8;, score=-3.472 total time=   1.8s
# [CV 5/5; 31/108] START activation=relu, dropout_rate=0.1, num_layers=3, optimizer=adam, units=8
# [CV 5/5; 31/108] END activation=relu, dropout_rate=0.1, num_layers=3, optimizer=adam, units=8;, score=-4.334 total time=   1.7s
# [CV 1/5; 32/108] START activation=relu, dropout_rate=0.1, num_layers=3, optimizer=adam, units=16
# [CV 1/5; 32/108] END activation=relu, dropout_rate=0.1, num_layers=3, optimizer=adam, units=16;, score=-1.278 total time=   1.9s
# [CV 2/5; 32/108] START activation=relu, dropout_rate=0.1, num_layers=3, optimizer=adam, units=16
# [CV 2/5; 32/108] END activation=relu, dropout_rate=0.1, num_layers=3, optimizer=adam, units=16;, score=-8.261 total time=   1.9s
# [CV 3/5; 32/108] START activation=relu, dropout_rate=0.1, num_layers=3, optimizer=adam, units=16
# [CV 3/5; 32/108] END activation=relu, dropout_rate=0.1, num_layers=3, optimizer=adam, units=16;, score=-0.637 total time=   1.9s
# [CV 4/5; 32/108] START activation=relu, dropout_rate=0.1, num_layers=3, optimizer=adam, units=16
# [CV 4/5; 32/108] END activation=relu, dropout_rate=0.1, num_layers=3, optimizer=adam, units=16;, score=-0.614 total time=   1.8s
# [CV 5/5; 32/108] START activation=relu, dropout_rate=0.1, num_layers=3, optimizer=adam, units=16
# [CV 5/5; 32/108] END activation=relu, dropout_rate=0.1, num_layers=3, optimizer=adam, units=16;, score=-0.307 total time=   1.7s
# [CV 1/5; 33/108] START activation=relu, dropout_rate=0.1, num_layers=3, optimizer=adam, units=32
# [CV 1/5; 33/108] END activation=relu, dropout_rate=0.1, num_layers=3, optimizer=adam, units=32;, score=-0.330 total time=   2.3s
# [CV 2/5; 33/108] START activation=relu, dropout_rate=0.1, num_layers=3, optimizer=adam, units=32
# [CV 2/5; 33/108] END activation=relu, dropout_rate=0.1, num_layers=3, optimizer=adam, units=32;, score=-1.722 total time=   2.0s
# [CV 3/5; 33/108] START activation=relu, dropout_rate=0.1, num_layers=3, optimizer=adam, units=32
# [CV 3/5; 33/108] END activation=relu, dropout_rate=0.1, num_layers=3, optimizer=adam, units=32;, score=-0.223 total time=   1.9s
# [CV 4/5; 33/108] START activation=relu, dropout_rate=0.1, num_layers=3, optimizer=adam, units=32
# [CV 4/5; 33/108] END activation=relu, dropout_rate=0.1, num_layers=3, optimizer=adam, units=32;, score=-0.071 total time=   1.9s
# [CV 5/5; 33/108] START activation=relu, dropout_rate=0.1, num_layers=3, optimizer=adam, units=32
# [CV 5/5; 33/108] END activation=relu, dropout_rate=0.1, num_layers=3, optimizer=adam, units=32;, score=0.317 total time=   1.8s
# [CV 1/5; 34/108] START activation=relu, dropout_rate=0.1, num_layers=3, optimizer=sgd, units=8
# [CV 1/5; 34/108] END activation=relu, dropout_rate=0.1, num_layers=3, optimizer=sgd, units=8;, score=-2.273 total time=   1.7s
# [CV 2/5; 34/108] START activation=relu, dropout_rate=0.1, num_layers=3, optimizer=sgd, units=8
# [CV 2/5; 34/108] END activation=relu, dropout_rate=0.1, num_layers=3, optimizer=sgd, units=8;, score=-16.215 total time=   1.7s
# [CV 3/5; 34/108] START activation=relu, dropout_rate=0.1, num_layers=3, optimizer=sgd, units=8
# [CV 3/5; 34/108] END activation=relu, dropout_rate=0.1, num_layers=3, optimizer=sgd, units=8;, score=-14.181 total time=   1.7s
# [CV 4/5; 34/108] START activation=relu, dropout_rate=0.1, num_layers=3, optimizer=sgd, units=8
# [CV 4/5; 34/108] END activation=relu, dropout_rate=0.1, num_layers=3, optimizer=sgd, units=8;, score=-2.178 total time=   1.9s
# [CV 5/5; 34/108] START activation=relu, dropout_rate=0.1, num_layers=3, optimizer=sgd, units=8
# [CV 5/5; 34/108] END activation=relu, dropout_rate=0.1, num_layers=3, optimizer=sgd, units=8;, score=-2.896 total time=   2.1s
# [CV 1/5; 35/108] START activation=relu, dropout_rate=0.1, num_layers=3, optimizer=sgd, units=16
# [CV 1/5; 35/108] END activation=relu, dropout_rate=0.1, num_layers=3, optimizer=sgd, units=16;, score=-0.298 total time=   2.1s
# [CV 2/5; 35/108] START activation=relu, dropout_rate=0.1, num_layers=3, optimizer=sgd, units=16
# [CV 2/5; 35/108] END activation=relu, dropout_rate=0.1, num_layers=3, optimizer=sgd, units=16;, score=-6.467 total time=   1.9s
# [CV 3/5; 35/108] START activation=relu, dropout_rate=0.1, num_layers=3, optimizer=sgd, units=16
# [CV 3/5; 35/108] END activation=relu, dropout_rate=0.1, num_layers=3, optimizer=sgd, units=16;, score=-0.407 total time=   1.9s
# [CV 4/5; 35/108] START activation=relu, dropout_rate=0.1, num_layers=3, optimizer=sgd, units=16
# [CV 4/5; 35/108] END activation=relu, dropout_rate=0.1, num_layers=3, optimizer=sgd, units=16;, score=-0.774 total time=   1.9s
# [CV 5/5; 35/108] START activation=relu, dropout_rate=0.1, num_layers=3, optimizer=sgd, units=16
# [CV 5/5; 35/108] END activation=relu, dropout_rate=0.1, num_layers=3, optimizer=sgd, units=16;, score=-0.037 total time=   1.8s
# [CV 1/5; 36/108] START activation=relu, dropout_rate=0.1, num_layers=3, optimizer=sgd, units=32
# [CV 1/5; 36/108] END activation=relu, dropout_rate=0.1, num_layers=3, optimizer=sgd, units=32;, score=0.074 total time=   1.8s
# [CV 2/5; 36/108] START activation=relu, dropout_rate=0.1, num_layers=3, optimizer=sgd, units=32
# [CV 2/5; 36/108] END activation=relu, dropout_rate=0.1, num_layers=3, optimizer=sgd, units=32;, score=-1.817 total time=   1.8s
# [CV 3/5; 36/108] START activation=relu, dropout_rate=0.1, num_layers=3, optimizer=sgd, units=32
# [CV 3/5; 36/108] END activation=relu, dropout_rate=0.1, num_layers=3, optimizer=sgd, units=32;, score=0.048 total time=   1.8s
# [CV 4/5; 36/108] START activation=relu, dropout_rate=0.1, num_layers=3, optimizer=sgd, units=32
# [CV 4/5; 36/108] END activation=relu, dropout_rate=0.1, num_layers=3, optimizer=sgd, units=32;, score=-0.392 total time=   2.5s
# [CV 5/5; 36/108] START activation=relu, dropout_rate=0.1, num_layers=3, optimizer=sgd, units=32
# [CV 5/5; 36/108] END activation=relu, dropout_rate=0.1, num_layers=3, optimizer=sgd, units=32;, score=0.190 total time=   1.8s
# [CV 1/5; 37/108] START activation=relu, dropout_rate=0.2, num_layers=1, optimizer=adam, units=8
# [CV 1/5; 37/108] END activation=relu, dropout_rate=0.2, num_layers=1, optimizer=adam, units=8;, score=-28.834 total time=   1.4s
# [CV 2/5; 37/108] START activation=relu, dropout_rate=0.2, num_layers=1, optimizer=adam, units=8
# [CV 2/5; 37/108] END activation=relu, dropout_rate=0.2, num_layers=1, optimizer=adam, units=8;, score=-142.723 total time=   1.4s
# [CV 3/5; 37/108] START activation=relu, dropout_rate=0.2, num_layers=1, optimizer=adam, units=8
# [CV 3/5; 37/108] END activation=relu, dropout_rate=0.2, num_layers=1, optimizer=adam, units=8;, score=-52.728 total time=   1.4s
# [CV 4/5; 37/108] START activation=relu, dropout_rate=0.2, num_layers=1, optimizer=adam, units=8
# [CV 4/5; 37/108] END activation=relu, dropout_rate=0.2, num_layers=1, optimizer=adam, units=8;, score=-64.411 total time=   1.3s
# [CV 5/5; 37/108] START activation=relu, dropout_rate=0.2, num_layers=1, optimizer=adam, units=8
# [CV 5/5; 37/108] END activation=relu, dropout_rate=0.2, num_layers=1, optimizer=adam, units=8;, score=-39.152 total time=   1.3s
# [CV 1/5; 38/108] START activation=relu, dropout_rate=0.2, num_layers=1, optimizer=adam, units=16
# [CV 1/5; 38/108] END activation=relu, dropout_rate=0.2, num_layers=1, optimizer=adam, units=16;, score=-8.351 total time=   1.3s
# [CV 2/5; 38/108] START activation=relu, dropout_rate=0.2, num_layers=1, optimizer=adam, units=16
# [CV 2/5; 38/108] END activation=relu, dropout_rate=0.2, num_layers=1, optimizer=adam, units=16;, score=-47.328 total time=   1.3s
# [CV 3/5; 38/108] START activation=relu, dropout_rate=0.2, num_layers=1, optimizer=adam, units=16
# [CV 3/5; 38/108] END activation=relu, dropout_rate=0.2, num_layers=1, optimizer=adam, units=16;, score=-11.633 total time=   1.4s
# [CV 4/5; 38/108] START activation=relu, dropout_rate=0.2, num_layers=1, optimizer=adam, units=16
# [CV 4/5; 38/108] END activation=relu, dropout_rate=0.2, num_layers=1, optimizer=adam, units=16;, score=-10.821 total time=   1.3s
# [CV 5/5; 38/108] START activation=relu, dropout_rate=0.2, num_layers=1, optimizer=adam, units=16
# [CV 5/5; 38/108] END activation=relu, dropout_rate=0.2, num_layers=1, optimizer=adam, units=16;, score=-11.708 total time=   1.2s
# [CV 1/5; 39/108] START activation=relu, dropout_rate=0.2, num_layers=1, optimizer=adam, units=32
# [CV 1/5; 39/108] END activation=relu, dropout_rate=0.2, num_layers=1, optimizer=adam, units=32;, score=-4.598 total time=   1.6s
# [CV 2/5; 39/108] START activation=relu, dropout_rate=0.2, num_layers=1, optimizer=adam, units=32
# [CV 2/5; 39/108] END activation=relu, dropout_rate=0.2, num_layers=1, optimizer=adam, units=32;, score=-21.428 total time=   2.1s
# [CV 3/5; 39/108] START activation=relu, dropout_rate=0.2, num_layers=1, optimizer=adam, units=32
# [CV 3/5; 39/108] END activation=relu, dropout_rate=0.2, num_layers=1, optimizer=adam, units=32;, score=-3.929 total time=   1.7s
# [CV 4/5; 39/108] START activation=relu, dropout_rate=0.2, num_layers=1, optimizer=adam, units=32
# [CV 4/5; 39/108] END activation=relu, dropout_rate=0.2, num_layers=1, optimizer=adam, units=32;, score=-1.757 total time=   1.7s
# [CV 5/5; 39/108] START activation=relu, dropout_rate=0.2, num_layers=1, optimizer=adam, units=32
# [CV 5/5; 39/108] END activation=relu, dropout_rate=0.2, num_layers=1, optimizer=adam, units=32;, score=-1.063 total time=   1.3s
# [CV 1/5; 40/108] START activation=relu, dropout_rate=0.2, num_layers=1, optimizer=sgd, units=8
# [CV 1/5; 40/108] END activation=relu, dropout_rate=0.2, num_layers=1, optimizer=sgd, units=8;, score=-34.234 total time=   1.3s
# [CV 2/5; 40/108] START activation=relu, dropout_rate=0.2, num_layers=1, optimizer=sgd, units=8
# [CV 2/5; 40/108] END activation=relu, dropout_rate=0.2, num_layers=1, optimizer=sgd, units=8;, score=-161.250 total time=   1.3s
# [CV 3/5; 40/108] START activation=relu, dropout_rate=0.2, num_layers=1, optimizer=sgd, units=8
# [CV 3/5; 40/108] END activation=relu, dropout_rate=0.2, num_layers=1, optimizer=sgd, units=8;, score=-55.656 total time=   1.3s
# [CV 4/5; 40/108] START activation=relu, dropout_rate=0.2, num_layers=1, optimizer=sgd, units=8
# [CV 4/5; 40/108] END activation=relu, dropout_rate=0.2, num_layers=1, optimizer=sgd, units=8;, score=-67.996 total time=   1.3s
# [CV 5/5; 40/108] START activation=relu, dropout_rate=0.2, num_layers=1, optimizer=sgd, units=8
# [CV 5/5; 40/108] END activation=relu, dropout_rate=0.2, num_layers=1, optimizer=sgd, units=8;, score=-30.863 total time=   1.2s
# [CV 1/5; 41/108] START activation=relu, dropout_rate=0.2, num_layers=1, optimizer=sgd, units=16
# [CV 1/5; 41/108] END activation=relu, dropout_rate=0.2, num_layers=1, optimizer=sgd, units=16;, score=-8.340 total time=   1.2s
# [CV 2/5; 41/108] START activation=relu, dropout_rate=0.2, num_layers=1, optimizer=sgd, units=16
# [CV 2/5; 41/108] END activation=relu, dropout_rate=0.2, num_layers=1, optimizer=sgd, units=16;, score=-37.764 total time=   1.2s
# [CV 3/5; 41/108] START activation=relu, dropout_rate=0.2, num_layers=1, optimizer=sgd, units=16
# [CV 3/5; 41/108] END activation=relu, dropout_rate=0.2, num_layers=1, optimizer=sgd, units=16;, score=-23.139 total time=   1.2s
# [CV 4/5; 41/108] START activation=relu, dropout_rate=0.2, num_layers=1, optimizer=sgd, units=16
# [CV 4/5; 41/108] END activation=relu, dropout_rate=0.2, num_layers=1, optimizer=sgd, units=16;, score=-13.012 total time=   1.8s
# [CV 5/5; 41/108] START activation=relu, dropout_rate=0.2, num_layers=1, optimizer=sgd, units=16
# [CV 5/5; 41/108] END activation=relu, dropout_rate=0.2, num_layers=1, optimizer=sgd, units=16;, score=-23.783 total time=   1.3s
# [CV 1/5; 42/108] START activation=relu, dropout_rate=0.2, num_layers=1, optimizer=sgd, units=32
# [CV 1/5; 42/108] END activation=relu, dropout_rate=0.2, num_layers=1, optimizer=sgd, units=32;, score=-2.077 total time=   1.3s
# [CV 2/5; 42/108] START activation=relu, dropout_rate=0.2, num_layers=1, optimizer=sgd, units=32
# [CV 2/5; 42/108] END activation=relu, dropout_rate=0.2, num_layers=1, optimizer=sgd, units=32;, score=-14.159 total time=   1.3s
# [CV 3/5; 42/108] START activation=relu, dropout_rate=0.2, num_layers=1, optimizer=sgd, units=32
# [CV 3/5; 42/108] END activation=relu, dropout_rate=0.2, num_layers=1, optimizer=sgd, units=32;, score=-2.891 total time=   1.3s
# [CV 4/5; 42/108] START activation=relu, dropout_rate=0.2, num_layers=1, optimizer=sgd, units=32
# [CV 4/5; 42/108] END activation=relu, dropout_rate=0.2, num_layers=1, optimizer=sgd, units=32;, score=-2.181 total time=   1.3s
# [CV 5/5; 42/108] START activation=relu, dropout_rate=0.2, num_layers=1, optimizer=sgd, units=32
# [CV 5/5; 42/108] END activation=relu, dropout_rate=0.2, num_layers=1, optimizer=sgd, units=32;, score=-1.441 total time=   1.2s
# [CV 1/5; 43/108] START activation=relu, dropout_rate=0.2, num_layers=2, optimizer=adam, units=8
# [CV 1/5; 43/108] END activation=relu, dropout_rate=0.2, num_layers=2, optimizer=adam, units=8;, score=-46.191 total time=   1.5s
# [CV 2/5; 43/108] START activation=relu, dropout_rate=0.2, num_layers=2, optimizer=adam, units=8
# [CV 2/5; 43/108] END activation=relu, dropout_rate=0.2, num_layers=2, optimizer=adam, units=8;, score=-55.472 total time=   1.4s
# [CV 3/5; 43/108] START activation=relu, dropout_rate=0.2, num_layers=2, optimizer=adam, units=8
# [CV 3/5; 43/108] END activation=relu, dropout_rate=0.2, num_layers=2, optimizer=adam, units=8;, score=-17.323 total time=   1.4s
# [CV 4/5; 43/108] START activation=relu, dropout_rate=0.2, num_layers=2, optimizer=adam, units=8
# ...
# [CV 2/5; 95/108] END activation=sigmoid, dropout_rate=0.2, num_layers=1, optimizer=sgd, units=16;, score=-150.634 total time=   1.9s
# [CV 3/5; 95/108] START activation=sigmoid, dropout_rate=0.2, num_layers=1, optimizer=sgd, units=16
# [CV 3/5; 95/108] END activation=sigmoid, dropout_rate=0.2, num_layers=1, optimizer=sgd, units=16;, score=-62.381 total time=   1.4s
# [CV 4/5; 95/108] START activation=sigmoid, dropout_rate=0.2, num_layers=1, optimizer=sgd, units=16
# [CV 4/5; 95/108] END activation=sigmoid, dropout_rate=0.2, num_layers=1, optimizer=sgd, units=16;, score=-69.834 total time=   1.4s
# [CV 5/5; 95/108] START activation=sigmoid, dropout_rate=0.2, num_layers=1, optimizer=sgd, units=16
# [CV 5/5; 95/108] END activation=sigmoid, dropout_rate=0.2, num_layers=1, optimizer=sgd, units=16;, score=-61.069 total time=   1.3s
# [CV 1/5; 96/108] START activation=sigmoid, dropout_rate=0.2, num_layers=1, optimizer=sgd, units=32
# [CV 1/5; 96/108] END activation=sigmoid, dropout_rate=0.2, num_layers=1, optimizer=sgd, units=32;, score=-43.952 total time=   1.4s
# [CV 2/5; 96/108] START activation=sigmoid, dropout_rate=0.2, num_layers=1, optimizer=sgd, units=32
# [CV 2/5; 96/108] END activation=sigmoid, dropout_rate=0.2, num_layers=1, optimizer=sgd, units=32;, score=-139.832 total time=   1.3s
# [CV 3/5; 96/108] START activation=sigmoid, dropout_rate=0.2, num_layers=1, optimizer=sgd, units=32
# [CV 3/5; 96/108] END activation=sigmoid, dropout_rate=0.2, num_layers=1, optimizer=sgd, units=32;, score=-56.792 total time=   1.3s
# [CV 4/5; 96/108] START activation=sigmoid, dropout_rate=0.2, num_layers=1, optimizer=sgd, units=32
# [CV 4/5; 96/108] END activation=sigmoid, dropout_rate=0.2, num_layers=1, optimizer=sgd, units=32;, score=-64.999 total time=   1.3s
# [CV 5/5; 96/108] START activation=sigmoid, dropout_rate=0.2, num_layers=1, optimizer=sgd, units=32
# [CV 5/5; 96/108] END activation=sigmoid, dropout_rate=0.2, num_layers=1, optimizer=sgd, units=32;, score=-57.675 total time=   1.2s
# [CV 1/5; 97/108] START activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=adam, units=8
# [CV 1/5; 97/108] END activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=adam, units=8;, score=-52.344 total time=   1.4s
# [CV 2/5; 97/108] START activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=adam, units=8
# [CV 2/5; 97/108] END activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=adam, units=8;, score=-155.464 total time=   1.4s
# [CV 3/5; 97/108] START activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=adam, units=8
# [CV 3/5; 97/108] END activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=adam, units=8;, score=-65.552 total time=   1.4s
# [CV 4/5; 97/108] START activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=adam, units=8
# [CV 4/5; 97/108] END activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=adam, units=8;, score=-74.963 total time=   2.1s
# [CV 5/5; 97/108] START activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=adam, units=8
# [CV 5/5; 97/108] END activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=adam, units=8;, score=-65.283 total time=   1.6s
# [CV 1/5; 98/108] START activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=adam, units=16
# [CV 1/5; 98/108] END activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=adam, units=16;, score=-49.424 total time=   1.7s
# [CV 2/5; 98/108] START activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=adam, units=16
# [CV 2/5; 98/108] END activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=adam, units=16;, score=-147.903 total time=   1.6s
# [CV 3/5; 98/108] START activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=adam, units=16
# [CV 3/5; 98/108] END activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=adam, units=16;, score=-58.028 total time=   1.5s
# [CV 4/5; 98/108] START activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=adam, units=16
# [CV 4/5; 98/108] END activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=adam, units=16;, score=-68.592 total time=   1.5s
# [CV 5/5; 98/108] START activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=adam, units=16
# [CV 5/5; 98/108] END activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=adam, units=16;, score=-65.116 total time=   1.4s
# [CV 1/5; 99/108] START activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=adam, units=32
# [CV 1/5; 99/108] END activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=adam, units=32;, score=-48.208 total time=   1.5s
# [CV 2/5; 99/108] START activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=adam, units=32
# [CV 2/5; 99/108] END activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=adam, units=32;, score=-140.934 total time=   1.5s
# [CV 3/5; 99/108] START activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=adam, units=32
# [CV 3/5; 99/108] END activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=adam, units=32;, score=-56.633 total time=   1.4s
# [CV 4/5; 99/108] START activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=adam, units=32
# [CV 4/5; 99/108] END activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=adam, units=32;, score=-67.225 total time=   1.5s
# [CV 5/5; 99/108] START activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=adam, units=32
# [CV 5/5; 99/108] END activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=adam, units=32;, score=-54.598 total time=   2.1s
# [CV 1/5; 100/108] START activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=sgd, units=8
# [CV 1/5; 100/108] END activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=sgd, units=8;, score=-52.812 total time=   1.7s
# [CV 2/5; 100/108] START activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=sgd, units=8
# [CV 2/5; 100/108] END activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=sgd, units=8;, score=-154.998 total time=   1.6s
# [CV 3/5; 100/108] START activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=sgd, units=8
# [CV 3/5; 100/108] END activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=sgd, units=8;, score=-64.240 total time=   1.5s
# [CV 4/5; 100/108] START activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=sgd, units=8
# [CV 4/5; 100/108] END activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=sgd, units=8;, score=-74.143 total time=   1.5s
# [CV 5/5; 100/108] START activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=sgd, units=8
# [CV 5/5; 100/108] END activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=sgd, units=8;, score=-67.246 total time=   1.4s
# [CV 1/5; 101/108] START activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=sgd, units=16
# [CV 1/5; 101/108] END activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=sgd, units=16;, score=-49.726 total time=   1.5s
# [CV 2/5; 101/108] START activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=sgd, units=16
# [CV 2/5; 101/108] END activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=sgd, units=16;, score=-148.457 total time=   1.4s
# [CV 3/5; 101/108] START activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=sgd, units=16
# [CV 3/5; 101/108] END activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=sgd, units=16;, score=-59.920 total time=   1.4s
# [CV 4/5; 101/108] START activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=sgd, units=16
# [CV 4/5; 101/108] END activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=sgd, units=16;, score=-73.268 total time=   1.4s
# [CV 5/5; 101/108] START activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=sgd, units=16
# [CV 5/5; 101/108] END activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=sgd, units=16;, score=-63.184 total time=   1.4s
# [CV 1/5; 102/108] START activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=sgd, units=32
# [CV 1/5; 102/108] END activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=sgd, units=32;, score=-45.785 total time=   1.9s
# [CV 2/5; 102/108] START activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=sgd, units=32
# [CV 2/5; 102/108] END activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=sgd, units=32;, score=-140.999 total time=   1.7s
# [CV 3/5; 102/108] START activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=sgd, units=32
# [CV 3/5; 102/108] END activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=sgd, units=32;, score=-58.018 total time=   1.7s
# [CV 4/5; 102/108] START activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=sgd, units=32
# [CV 4/5; 102/108] END activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=sgd, units=32;, score=-65.111 total time=   1.6s
# [CV 5/5; 102/108] START activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=sgd, units=32
# [CV 5/5; 102/108] END activation=sigmoid, dropout_rate=0.2, num_layers=2, optimizer=sgd, units=32;, score=-61.408 total time=   1.5s
# [CV 1/5; 103/108] START activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=adam, units=8
# [CV 1/5; 103/108] END activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=adam, units=8;, score=-50.818 total time=   1.8s
# [CV 2/5; 103/108] START activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=adam, units=8
# [CV 2/5; 103/108] END activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=adam, units=8;, score=-152.847 total time=   1.7s
# [CV 3/5; 103/108] START activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=adam, units=8
# [CV 3/5; 103/108] END activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=adam, units=8;, score=-62.935 total time=   1.6s
# [CV 4/5; 103/108] START activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=adam, units=8
# [CV 4/5; 103/108] END activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=adam, units=8;, score=-73.636 total time=   1.6s
# [CV 5/5; 103/108] START activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=adam, units=8
# [CV 5/5; 103/108] END activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=adam, units=8;, score=-66.933 total time=   1.6s
# [CV 1/5; 104/108] START activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=adam, units=16
# [CV 1/5; 104/108] END activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=adam, units=16;, score=-48.695 total time=   2.2s
# [CV 2/5; 104/108] START activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=adam, units=16
# [CV 2/5; 104/108] END activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=adam, units=16;, score=-149.019 total time=   1.9s
# [CV 3/5; 104/108] START activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=adam, units=16
# [CV 3/5; 104/108] END activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=adam, units=16;, score=-60.327 total time=   1.9s
# [CV 4/5; 104/108] START activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=adam, units=16
# [CV 4/5; 104/108] END activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=adam, units=16;, score=-69.365 total time=   1.8s
# [CV 5/5; 104/108] START activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=adam, units=16
# [CV 5/5; 104/108] END activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=adam, units=16;, score=-61.618 total time=   1.7s
# [CV 1/5; 105/108] START activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=adam, units=32
# [CV 1/5; 105/108] END activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=adam, units=32;, score=-44.559 total time=   1.7s
# [CV 2/5; 105/108] START activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=adam, units=32
# [CV 2/5; 105/108] END activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=adam, units=32;, score=-138.541 total time=   1.8s
# [CV 3/5; 105/108] START activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=adam, units=32
# [CV 3/5; 105/108] END activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=adam, units=32;, score=-55.756 total time=   1.7s
# [CV 4/5; 105/108] START activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=adam, units=32
# [CV 4/5; 105/108] END activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=adam, units=32;, score=-62.268 total time=   1.6s
# [CV 5/5; 105/108] START activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=adam, units=32
# [CV 5/5; 105/108] END activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=adam, units=32;, score=-56.154 total time=   1.5s
# [CV 1/5; 106/108] START activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=sgd, units=8
# [CV 1/5; 106/108] END activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=sgd, units=8;, score=-52.985 total time=   2.5s
# [CV 2/5; 106/108] START activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=sgd, units=8
# [CV 2/5; 106/108] END activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=sgd, units=8;, score=-159.301 total time=   1.9s
# [CV 3/5; 106/108] START activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=sgd, units=8
# [CV 3/5; 106/108] END activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=sgd, units=8;, score=-64.648 total time=   1.8s
# [CV 4/5; 106/108] START activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=sgd, units=8
# [CV 4/5; 106/108] END activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=sgd, units=8;, score=-71.875 total time=   1.8s
# [CV 5/5; 106/108] START activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=sgd, units=8
# [CV 5/5; 106/108] END activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=sgd, units=8;, score=-66.278 total time=   1.8s
# [CV 1/5; 107/108] START activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=sgd, units=16
# [CV 1/5; 107/108] END activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=sgd, units=16;, score=-49.497 total time=   1.7s
# [CV 2/5; 107/108] START activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=sgd, units=16
# [CV 2/5; 107/108] END activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=sgd, units=16;, score=-151.377 total time=   1.6s
# [CV 3/5; 107/108] START activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=sgd, units=16
# [CV 3/5; 107/108] END activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=sgd, units=16;, score=-62.251 total time=   1.6s
# [CV 4/5; 107/108] START activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=sgd, units=16
# [CV 4/5; 107/108] END activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=sgd, units=16;, score=-73.359 total time=   1.6s
# [CV 5/5; 107/108] START activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=sgd, units=16
# [CV 5/5; 107/108] END activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=sgd, units=16;, score=-64.736 total time=   1.5s
# [CV 1/5; 108/108] START activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=sgd, units=32
# [CV 1/5; 108/108] END activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=sgd, units=32;, score=-46.357 total time=   2.5s
# [CV 2/5; 108/108] START activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=sgd, units=32
# [CV 2/5; 108/108] END activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=sgd, units=32;, score=-144.386 total time=   1.9s
# [CV 3/5; 108/108] START activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=sgd, units=32
# [CV 3/5; 108/108] END activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=sgd, units=32;, score=-57.352 total time=   1.8s
# [CV 4/5; 108/108] START activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=sgd, units=32
# [CV 4/5; 108/108] END activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=sgd, units=32;, score=-61.903 total time=   1.9s
# [CV 5/5; 108/108] START activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=sgd, units=32
# [CV 5/5; 108/108] END activation=sigmoid, dropout_rate=0.2, num_layers=3, optimizer=sgd, units=32;, score=-57.336 total time=   1.7s

# %%
print('Best: {}, using {}'.format(grid_result.best_score_, grid_result.best_params_))
# Out:
# Best: -0.33577756086116295, using {'activation': 'relu', 'dropout_rate': 0.0, 'num_layers': 3, 'optimizer': 'adam', 'units': 32}

# %% [markdown]
# Building model using best parameters from previous gridsearch

# %%
build_model = KerasRegressor(model=create_model, verbose=0, activation='relu', dropout_rate=0.0, num_layers=3, units=32, optimizer='adam')

# %% [markdown]
# Gridsearch for other parameters:
# - batch_size
# - epochs

# %%
param_grid = {'batch_size':[500,1000,5000],
              'epochs':[30,40,50,60]}

# %%
grid = GridSearchCV(estimator=build_model, param_grid=param_grid, cv=KFold(), verbose=10)
grid_result = grid.fit(x,y)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5; 1/12] START batch_size=500, epochs=30..................................
# [CV 1/5; 1/12] END ...batch_size=500, epochs=30;, score=0.700 total time=   3.3s
# [CV 2/5; 1/12] START batch_size=500, epochs=30..................................
# [CV 2/5; 1/12] END ...batch_size=500, epochs=30;, score=0.732 total time=   2.7s
# [CV 3/5; 1/12] START batch_size=500, epochs=30..................................
# [CV 3/5; 1/12] END ...batch_size=500, epochs=30;, score=0.704 total time=   2.8s
# [CV 4/5; 1/12] START batch_size=500, epochs=30..................................
# [CV 4/5; 1/12] END ...batch_size=500, epochs=30;, score=0.668 total time=   2.5s
# [CV 5/5; 1/12] START batch_size=500, epochs=30..................................
# [CV 5/5; 1/12] END ...batch_size=500, epochs=30;, score=0.775 total time=   2.5s
# [CV 1/5; 2/12] START batch_size=500, epochs=40..................................
# [CV 1/5; 2/12] END ...batch_size=500, epochs=40;, score=0.733 total time=   3.6s
# [CV 2/5; 2/12] START batch_size=500, epochs=40..................................
# [CV 2/5; 2/12] END ...batch_size=500, epochs=40;, score=0.634 total time=   3.1s
# [CV 3/5; 2/12] START batch_size=500, epochs=40..................................
# [CV 3/5; 2/12] END ...batch_size=500, epochs=40;, score=0.746 total time=   2.9s
# [CV 4/5; 2/12] START batch_size=500, epochs=40..................................
# [CV 4/5; 2/12] END ...batch_size=500, epochs=40;, score=0.862 total time=   3.0s
# [CV 5/5; 2/12] START batch_size=500, epochs=40..................................
# [CV 5/5; 2/12] END ...batch_size=500, epochs=40;, score=0.798 total time=   3.1s
# [CV 1/5; 3/12] START batch_size=500, epochs=50..................................
# [CV 1/5; 3/12] END ...batch_size=500, epochs=50;, score=0.927 total time=   3.4s
# [CV 2/5; 3/12] START batch_size=500, epochs=50..................................
# [CV 2/5; 3/12] END ...batch_size=500, epochs=50;, score=0.957 total time=   3.3s
# [CV 3/5; 3/12] START batch_size=500, epochs=50..................................
# [CV 3/5; 3/12] END ...batch_size=500, epochs=50;, score=0.948 total time=   3.4s
# [CV 4/5; 3/12] START batch_size=500, epochs=50..................................
# [CV 4/5; 3/12] END ...batch_size=500, epochs=50;, score=0.946 total time=   3.4s
# [CV 5/5; 3/12] START batch_size=500, epochs=50..................................
# [CV 5/5; 3/12] END ...batch_size=500, epochs=50;, score=0.865 total time=   3.3s
# [CV 1/5; 4/12] START batch_size=500, epochs=60..................................
# [CV 1/5; 4/12] END ...batch_size=500, epochs=60;, score=0.866 total time=   3.8s
# [CV 2/5; 4/12] START batch_size=500, epochs=60..................................
# [CV 2/5; 4/12] END ...batch_size=500, epochs=60;, score=0.846 total time=   3.7s
# [CV 3/5; 4/12] START batch_size=500, epochs=60..................................
# [CV 3/5; 4/12] END ...batch_size=500, epochs=60;, score=0.877 total time=   3.5s
# [CV 4/5; 4/12] START batch_size=500, epochs=60..................................
# [CV 4/5; 4/12] END ...batch_size=500, epochs=60;, score=0.968 total time=   4.6s
# [CV 5/5; 4/12] START batch_size=500, epochs=60..................................
# [CV 5/5; 4/12] END ...batch_size=500, epochs=60;, score=0.935 total time=   3.9s
# [CV 1/5; 5/12] START batch_size=1000, epochs=30.................................
# [CV 1/5; 5/12] END ..batch_size=1000, epochs=30;, score=0.166 total time=   2.1s
# [CV 2/5; 5/12] START batch_size=1000, epochs=30.................................
# [CV 2/5; 5/12] END .batch_size=1000, epochs=30;, score=-1.665 total time=   2.0s
# [CV 3/5; 5/12] START batch_size=1000, epochs=30.................................
# [CV 3/5; 5/12] END ..batch_size=1000, epochs=30;, score=0.377 total time=   1.9s
# [CV 4/5; 5/12] START batch_size=1000, epochs=30.................................
# [CV 4/5; 5/12] END ..batch_size=1000, epochs=30;, score=0.264 total time=   1.9s
# [CV 5/5; 5/12] START batch_size=1000, epochs=30.................................
# [CV 5/5; 5/12] END ..batch_size=1000, epochs=30;, score=0.402 total time=   1.9s
# [CV 1/5; 6/12] START batch_size=1000, epochs=40.................................
# [CV 1/5; 6/12] END ..batch_size=1000, epochs=40;, score=0.200 total time=   2.2s
# [CV 2/5; 6/12] START batch_size=1000, epochs=40.................................
# [CV 2/5; 6/12] END .batch_size=1000, epochs=40;, score=-0.173 total time=   2.3s
# [CV 3/5; 6/12] START batch_size=1000, epochs=40.................................
# [CV 3/5; 6/12] END ..batch_size=1000, epochs=40;, score=0.351 total time=   2.2s
# [CV 4/5; 6/12] START batch_size=1000, epochs=40.................................
# [CV 4/5; 6/12] END ..batch_size=1000, epochs=40;, score=0.461 total time=   2.3s
# [CV 5/5; 6/12] START batch_size=1000, epochs=40.................................
# [CV 5/5; 6/12] END ..batch_size=1000, epochs=40;, score=0.618 total time=   2.3s
# [CV 1/5; 7/12] START batch_size=1000, epochs=50.................................
# [CV 1/5; 7/12] END ..batch_size=1000, epochs=50;, score=0.519 total time=   2.6s
# [CV 2/5; 7/12] START batch_size=1000, epochs=50.................................
# [CV 2/5; 7/12] END ..batch_size=1000, epochs=50;, score=0.351 total time=   3.1s
# [CV 3/5; 7/12] START batch_size=1000, epochs=50.................................
# [CV 3/5; 7/12] END ..batch_size=1000, epochs=50;, score=0.633 total time=   2.9s
# [CV 4/5; 7/12] START batch_size=1000, epochs=50.................................
# [CV 4/5; 7/12] END ..batch_size=1000, epochs=50;, score=0.674 total time=   2.8s
# [CV 5/5; 7/12] START batch_size=1000, epochs=50.................................
# [CV 5/5; 7/12] END ..batch_size=1000, epochs=50;, score=0.687 total time=   2.7s
# [CV 1/5; 8/12] START batch_size=1000, epochs=60.................................
# [CV 1/5; 8/12] END ..batch_size=1000, epochs=60;, score=0.453 total time=   2.9s
# [CV 2/5; 8/12] START batch_size=1000, epochs=60.................................
# [CV 2/5; 8/12] END ..batch_size=1000, epochs=60;, score=0.323 total time=   2.8s
# [CV 3/5; 8/12] START batch_size=1000, epochs=60.................................
# [CV 3/5; 8/12] END ..batch_size=1000, epochs=60;, score=0.573 total time=   2.7s
# [CV 4/5; 8/12] START batch_size=1000, epochs=60.................................
# [CV 4/5; 8/12] END ..batch_size=1000, epochs=60;, score=0.790 total time=   2.7s
# [CV 5/5; 8/12] START batch_size=1000, epochs=60.................................
# [CV 5/5; 8/12] END ..batch_size=1000, epochs=60;, score=0.754 total time=   2.7s
# [CV 1/5; 9/12] START batch_size=5000, epochs=30.................................
# [CV 1/5; 9/12] END .batch_size=5000, epochs=30;, score=-5.037 total time=   1.3s
# [CV 2/5; 9/12] START batch_size=5000, epochs=30.................................
# WARNING:tensorflow:5 out of the last 14 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8dca3f6ef0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [CV 2/5; 9/12] END batch_size=5000, epochs=30;, score=-30.369 total time=   1.2s
# [CV 3/5; 9/12] START batch_size=5000, epochs=30.................................
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8dca095fc0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [CV 3/5; 9/12] END batch_size=5000, epochs=30;, score=-13.539 total time=   1.3s
# [CV 4/5; 9/12] START batch_size=5000, epochs=30.................................
# [CV 4/5; 9/12] END .batch_size=5000, epochs=30;, score=-7.320 total time=   1.2s
# [CV 5/5; 9/12] START batch_size=5000, epochs=30.................................
# [CV 5/5; 9/12] END .batch_size=5000, epochs=30;, score=-8.134 total time=   1.3s
# [CV 1/5; 10/12] START batch_size=5000, epochs=40................................
# [CV 1/5; 10/12] END batch_size=5000, epochs=40;, score=-1.779 total time=   2.0s
# [CV 2/5; 10/12] START batch_size=5000, epochs=40................................
# [CV 2/5; 10/12] END batch_size=5000, epochs=40;, score=-17.190 total time=   1.7s
# [CV 3/5; 10/12] START batch_size=5000, epochs=40................................
# [CV 3/5; 10/12] END batch_size=5000, epochs=40;, score=-4.756 total time=   1.6s
# [CV 4/5; 10/12] START batch_size=5000, epochs=40................................
# [CV 4/5; 10/12] END batch_size=5000, epochs=40;, score=-3.243 total time=   1.5s
# [CV 5/5; 10/12] START batch_size=5000, epochs=40................................
# [CV 5/5; 10/12] END batch_size=5000, epochs=40;, score=-2.148 total time=   1.5s
# [CV 1/5; 11/12] START batch_size=5000, epochs=50................................
# [CV 1/5; 11/12] END batch_size=5000, epochs=50;, score=-1.297 total time=   1.5s
# [CV 2/5; 11/12] START batch_size=5000, epochs=50................................
# [CV 2/5; 11/12] END batch_size=5000, epochs=50;, score=-7.295 total time=   1.5s
# [CV 3/5; 11/12] START batch_size=5000, epochs=50................................
# [CV 3/5; 11/12] END batch_size=5000, epochs=50;, score=-0.954 total time=   1.5s
# [CV 4/5; 11/12] START batch_size=5000, epochs=50................................
# [CV 4/5; 11/12] END batch_size=5000, epochs=50;, score=-1.037 total time=   1.5s
# [CV 5/5; 11/12] START batch_size=5000, epochs=50................................
# [CV 5/5; 11/12] END batch_size=5000, epochs=50;, score=-2.325 total time=   1.5s
# [CV 1/5; 12/12] START batch_size=5000, epochs=60................................
# [CV 1/5; 12/12] END batch_size=5000, epochs=60;, score=-1.604 total time=   1.6s
# [CV 2/5; 12/12] START batch_size=5000, epochs=60................................
# [CV 2/5; 12/12] END batch_size=5000, epochs=60;, score=-5.850 total time=   1.6s
# [CV 3/5; 12/12] START batch_size=5000, epochs=60................................
# [CV 3/5; 12/12] END batch_size=5000, epochs=60;, score=-0.555 total time=   1.5s
# [CV 4/5; 12/12] START batch_size=5000, epochs=60................................
# [CV 4/5; 12/12] END batch_size=5000, epochs=60;, score=-0.709 total time=   1.5s
# [CV 5/5; 12/12] START batch_size=5000, epochs=60................................
# [CV 5/5; 12/12] END batch_size=5000, epochs=60;, score=-0.385 total time=   2.2s

# %%
print('Best: {}, using {}'.format(grid_result.best_score_, grid_result.best_params_))
# Out:
# Best: 0.9284028144940937, using {'batch_size': 500, 'epochs': 50}

# %%
plt.figure(figsize=(10,5))
grid_result_df = pd.DataFrame(grid_result.cv_results_)
mean_scores = grid_result_df.pivot_table(values='mean_test_score', index='param_batch_size', columns='param_epochs')
sns.heatmap(mean_scores, cmap="YlGnBu", annot=True, fmt=".2f")
# Out:
# <AxesSubplot:xlabel='param_epochs', ylabel='param_batch_size'>

# %%
best_model = grid.best_estimator_
history = best_model.history_

plt.plot(history['loss'])
plt.title('training loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %% [markdown]
# ### Creating final model using best parameters we found

# %%
model = create_model(activation='relu',dropout_rate=0.0, num_layers=3,optimizer='adam',units=32)
history = model.fit(x_train,y_train,epochs=50,batch_size=500)
# Out:
# Epoch 1/50
# 25/25 [==============================] - 1s 3ms/step - loss: 18145.0527
# Epoch 2/50
# 25/25 [==============================] - 0s 3ms/step - loss: 17075.8145
# Epoch 3/50
# 25/25 [==============================] - 0s 3ms/step - loss: 12525.6924
# Epoch 4/50
# 25/25 [==============================] - 0s 5ms/step - loss: 4088.4758
# Epoch 5/50
# 25/25 [==============================] - 0s 3ms/step - loss: 1645.7932
# Epoch 6/50
# 25/25 [==============================] - 0s 3ms/step - loss: 928.9557
# Epoch 7/50
# 25/25 [==============================] - 0s 3ms/step - loss: 609.8049
# Epoch 8/50
# 25/25 [==============================] - 0s 3ms/step - loss: 465.4378
# Epoch 9/50
# 25/25 [==============================] - 0s 3ms/step - loss: 395.7574
# Epoch 10/50
# 25/25 [==============================] - 0s 3ms/step - loss: 350.5471
# Epoch 11/50
# 25/25 [==============================] - 0s 3ms/step - loss: 314.7664
# Epoch 12/50
# 25/25 [==============================] - 0s 3ms/step - loss: 284.0903
# Epoch 13/50
# 25/25 [==============================] - 0s 3ms/step - loss: 256.8779
# Epoch 14/50
# 25/25 [==============================] - 0s 3ms/step - loss: 231.7004
# Epoch 15/50
# 25/25 [==============================] - 0s 3ms/step - loss: 208.9960
# Epoch 16/50
# 25/25 [==============================] - 0s 3ms/step - loss: 188.0576
# Epoch 17/50
# 25/25 [==============================] - 0s 3ms/step - loss: 169.9468
# Epoch 18/50
# 25/25 [==============================] - 0s 3ms/step - loss: 153.8686
# Epoch 19/50
# 25/25 [==============================] - 0s 4ms/step - loss: 139.6155
# Epoch 20/50
# 25/25 [==============================] - 0s 4ms/step - loss: 127.5522
# Epoch 21/50
# 25/25 [==============================] - 0s 3ms/step - loss: 117.1651
# Epoch 22/50
# 25/25 [==============================] - 0s 5ms/step - loss: 108.0624
# Epoch 23/50
# 25/25 [==============================] - 0s 3ms/step - loss: 100.1353
# Epoch 24/50
# 25/25 [==============================] - 0s 3ms/step - loss: 93.1527
# Epoch 25/50
# 25/25 [==============================] - 0s 3ms/step - loss: 86.9594
# Epoch 26/50
# 25/25 [==============================] - 0s 3ms/step - loss: 81.4625
# Epoch 27/50
# 25/25 [==============================] - 0s 3ms/step - loss: 76.4769
# Epoch 28/50
# 25/25 [==============================] - 0s 3ms/step - loss: 72.1729
# Epoch 29/50
# 25/25 [==============================] - 0s 3ms/step - loss: 68.1811
# Epoch 30/50
# 25/25 [==============================] - 0s 3ms/step - loss: 63.9862
# Epoch 31/50
# 25/25 [==============================] - 0s 3ms/step - loss: 60.2486
# Epoch 32/50
# 25/25 [==============================] - 0s 3ms/step - loss: 56.7512
# Epoch 33/50
# 25/25 [==============================] - 0s 3ms/step - loss: 53.3696
# Epoch 34/50
# 25/25 [==============================] - 0s 3ms/step - loss: 50.3329
# Epoch 35/50
# 25/25 [==============================] - 0s 3ms/step - loss: 47.2463
# Epoch 36/50
# 25/25 [==============================] - 0s 3ms/step - loss: 44.4684
# Epoch 37/50
# 25/25 [==============================] - 0s 3ms/step - loss: 41.6158
# Epoch 38/50
# 25/25 [==============================] - 0s 3ms/step - loss: 38.8715
# Epoch 39/50
# 25/25 [==============================] - 0s 3ms/step - loss: 36.3977
# Epoch 40/50
# 25/25 [==============================] - 0s 3ms/step - loss: 34.0226
# Epoch 41/50
# 25/25 [==============================] - 0s 4ms/step - loss: 31.7698
# Epoch 42/50
# 25/25 [==============================] - 0s 3ms/step - loss: 29.5995
# Epoch 43/50
# 25/25 [==============================] - 0s 3ms/step - loss: 27.6546
# Epoch 44/50
# 25/25 [==============================] - 0s 3ms/step - loss: 25.7730
# Epoch 45/50
# 25/25 [==============================] - 0s 3ms/step - loss: 24.1692
# Epoch 46/50
# 25/25 [==============================] - 0s 3ms/step - loss: 22.4915
# Epoch 47/50
# 25/25 [==============================] - 0s 3ms/step - loss: 21.0107
# Epoch 48/50
# 25/25 [==============================] - 0s 3ms/step - loss: 19.4956
# Epoch 49/50
# 25/25 [==============================] - 0s 3ms/step - loss: 17.9911
# Epoch 50/50
# 25/25 [==============================] - 0s 3ms/step - loss: 16.6277

# %%
y_pred = model.predict(x_test)
# Out:
# 94/94 [==============================] - 0s 1ms/step

# %% [markdown]
# Mean Squared Error

# %%
mean_squared_error(y_pred,y_test)
# Out:
# 16.565620710070103
